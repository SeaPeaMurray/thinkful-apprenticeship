# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('whitegrid')

file = "globalpowerplantdatabasev110/global_power_plant_database.csv"
power = pd.read_csv(file)

# %%
plt.figure(figsize=(16,10))
power['country'].value_counts()[:15].plot(kind='bar')
plt.title('Total power generation facilities per country: Largest 15', size=22)
plt.xlabel('Country code', size=16)
plt.ylabel('Number of facilities', size=16)
plt.show()

# %% [markdown]
# For the first illustration, we'll do something basic.
#
# Let's look at the amount of power generation facilities by country and graph the largest 15 beside one another. This seems to be a good starting visualization; it shows that the most prominent economies do in fact have large power infrastructures.

# %%
plt.figure(figsize=(16,10))
sns.distplot(np.log(power.groupby('country')['capacity_mw'].agg(np.std).dropna()),
             rug=True, norm_hist=True).set_title('Distribution of Megawatt Capacity variation per country', size=22)
plt.xlabel('Standard deviation of Megawatt Capacity aggregated by country on logarithmic scale', size=16)
plt.show()
# Out:
# C:\Users\seapea\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# The second illustration is a bit more complex.
#
# This is a distribution, or histogram, of the megawatt capacity (basic power output potential) across an entire country's infrastructure - scaled logarithmically. Without the scaling or normalization, outliers have extreme effects on the distribution. As expected, a Gaussian distribution is observed, with larger economies taking space on the extreme right, and those smaller on the left.
#
# The only improvement to this graph would probably be some identifiers of predominant countries and where they lie in the distribution.

# %%
# clean data from empty dates and fuel1 for time analyses
power1 = power[(power['fuel1'].notnull()) & (power['commissioning_year'].notnull())]
power1.loc[:, 'commissioning_year'] = power1.loc[:, 'commissioning_year'].map(int)

power2 = pd.DataFrame()
for val in power1['fuel1'].value_counts()[:6].index.values: # future proof for six most frequent fuels

    if val == 'Hydro':
        power2 = power1[power1['fuel1'] == val]
    else:
        power2 = power2.append(power1[power1['fuel1'] == val])

plt.figure(figsize=(16,10))
sns.violinplot(x='commissioning_year', y='fuel1', data=power2, inner='quartile', scale='count')
plt.title('Generator count by fuel type over time', size=22)
plt.xlabel('Commissioning year', size=16)
plt.ylabel('Fuel type', size=16)
plt.show()
# Out:
# C:\Users\seapea\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# This is another advanced visualization.
#
# It represents the distribution or count of the six most prevalent power generation facility technologies by their commission year. As expected, some green technologies, such as wind and solar, have seen significant increase over recent decades.
#
# The only addition I would make to this illustration would be to its dataset; without an idea of de- or recommission times, some values could be inaccurate.

# %%
plt.figure(figsize=(16,10))
# graph capacity summary statistics over time for Hydro and Coal
ax = sns.lineplot(x='commissioning_year', y='capacity_mw', 
                  data=power2[(power2['fuel1'] == 'Hydro') | (power2['fuel1'] == 'Coal')], 
                  hue='fuel1', estimator=np.median, ci=68, style='fuel1')
plt.setp(ax.get_legend().get_texts(), fontsize='16')
plt.title('Hydro and Coal generator megawatt capacity ratings over time', size=22)
plt.xlabel('Commissioning year', size=16)
plt.ylabel('Megawatt capacity', size=16)
plt.show()
# Out:
# C:\Users\seapea\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# The last visualization is also a bit complex.
#
# We are seeing the megawatt capacity ratings of water (Hydro) and coal facilities over time. We can expect trends correlating with major production demands - such as wars and population increases. An interesting observation is that generator commission appears rather spiky; this could be an effect of federal and corporate budget limitations. The band of each value represents the confidence interval of 68 percent - showing within which capacities 68 percent of generators commissioned that year fall.
#
# One addition that might provide a better insight of overall trends would be to use ARIMA and rolling average methods.

# %%
# Set a countries list for pulling crosstab below
# countries_of_interest = ['USA', 'CHN', 'GER', 'FRA', 'RUS', 'IND', 'JPN', 'CAN', 'BRA', 'ITA']

# Set renewable booleans on dataframe
# for df in [power, power1]:
#     df['renewable'] = pd.DataFrame([(power1['fuel1'] != 'Oil') & (power1['fuel1'] != 'Gas') & (power1['fuel1'] != 'Coal')]).T

# Create crosstab to group renewable or not against commissioning year prior to 2000 or not on countries of interest
# power_new = pd.crosstab([power1['country'], power1['commissioning_year'] < 2000], power1['renewable']).loc[countries_of_interest]

# Explore crosstab
# power_new.sum(level=0)
# power_new.columns.name
# power_new.loc['BRA'].plot(kind='bar')

# Hold these thoughts for another project...
