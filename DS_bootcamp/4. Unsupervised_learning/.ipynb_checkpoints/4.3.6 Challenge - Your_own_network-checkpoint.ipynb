# %% [markdown]
# # Design your own network
#
# ### This project uses a data set to work out neural network builds with SKLearn
#
# We will work through some of the CIFAR image dataset using Bernoulli Restricted Boltzmann Machines and Logistic Regression to extract worthy features from the photos.

# %%
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
from sklearn.neural_network import BernoulliRBM
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler

sns.set_style('darkgrid')
# %matplotlib inline

# %%
with open('../../../_Large_datasets/cifar-10-batches-py/data_batch_2', 'rb') as file:
    my_dict = pickle.load(file, encoding='bytes')
    
print(my_dict.keys())

X = pd.DataFrame(my_dict[b'data'])
y = pd.Series(my_dict[b'labels'])

print(y.value_counts())
# Out:
# dict_keys([b'batch_label', b'labels', b'data', b'filenames'])
# 7    1026
# 4    1010
# 2    1010
# 6    1008
# 1    1007
# 3     995
# 5     988
# 8     987
# 9     985
# 0     984
# dtype: int64

# %% [markdown]
# ### Notes: No imbalance present
#
# Class imbalance is not a problem, as we are seeing value_counts between 984 and 1026.

# %%
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

doggie = pd.DataFrame(X_scaled).loc[800].values

fig, ax = plt.subplots(2, 2, figsize=(16,16))
ax[0, 0].imshow(doggie.reshape(32, 32, 3))
ax[0, 0].title.set_text('First attempt, invalid ravel')
ax[0, 1].imshow(doggie[:1024].reshape(32, 32))
ax[0, 1].title.set_text('One color of image')
ax[1, 0].imshow(doggie[1024:2048].reshape(32, 32))
ax[1, 0].title.set_text('Green shades inadvertently displayed in red')
ax[1, 1].imshow(doggie.reshape(3, 32, 32).transpose(1, 2, 0), interpolation='bicubic')
ax[1, 1].title.set_text('Full RGB image of dog')
plt.suptitle('Dog images', size=20)
plt.show()

# %% [markdown]
# ### Deducing how the images work as files
#
# To have a better understanding of the files we are working with, I set out to visualize a dog image. The first attempt repeated the image in smaller sections, followed by a few with the values of the wrong color spectrum represented. The final image is the true representation of the RGB image.

# %%
# Creating train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2)

rbm = BernoulliRBM(n_components=250, n_iter=50, learning_rate=0.001)
clf_log = LogisticRegression(solver='lbfgs', multi_class='multinomial')
clf_rbm_log = Pipeline(steps=[('rbm', rbm), ('log', clf_log)])

clf_rbm_log.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('rbm', BernoulliRBM(batch_size=10, learning_rate=0.001, n_components=250, n_iter=50,
#        random_state=None, verbose=0)), ('log', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='multinomial',
#           n_jobs=1, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False))])

# %% [markdown]
# ### Notes: n_components=250
#
# I am sticking with the higher value of n_components=250. I initially set this before understanding the RBM approach, and I'd like to keep it as I'm curious to see if the features are much different when the component count is high.

# %%
y_pred = clf_rbm_log.predict(X_test)
fig, ax = plt.subplots(figsize=(16, 9))
sns.heatmap(confusion_matrix(y_test, y_pred), ax=ax)
ax.title.set_text('Heatmap of actual versus predicted values')
plt.show()
print('BernoulliRBM and Logistic Regression score: {}'.format(clf_rbm_log.score(X_test, y_test)))
# Out:
# BernoulliRBM and Logistic Regression score: 0.385

# %% [markdown]
# ### Notes: Heatmap of true and pred; overall score
#
# The heatmap shows that all classes are represented somewhat. Earlier trials resulted in a single class of predictions - BernoulliRBM requires that input values lie between 0 and 1. Scaling was able to fix the single class prediction.
#
# The overall scores improved with the scaling as well, changing from one class entirely correct at about nine percent, to the results above.

# %%
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.45      0.42      0.43       209
#           1       0.43      0.45      0.44       200
#           2       0.27      0.29      0.28       191
#           3       0.31      0.26      0.28       211
#           4       0.36      0.33      0.34       216
#           5       0.34      0.32      0.33       206
#           6       0.37      0.43      0.40       199
#           7       0.39      0.41      0.40       172
#           8       0.50      0.59      0.54       186
#           9       0.41      0.39      0.40       210
#
# avg / total       0.38      0.39      0.38      2000

# %% [markdown]
# ### Notes: Classification report
#
# We can see that the scores are robust across the spectrum; precision, recall, and accuracy are all sitting at similar values - this is a good sign.

# %%
# Need to rescale output of components for imaging
scaled_comps = scaler.fit_transform(rbm.components_)

plt.figure(figsize=(16, 16))
# Requires enumerate to track component number and still build subplots of random components
for i, val in enumerate(np.random.randint(0, len(scaled_comps), size=144)):
    plt.subplot(12, 12, i + 1)
    plt.imshow(scaled_comps[val].reshape(3, 32, 32).transpose(1, 2, 0), cmap=plt.cm.gray_r)
    # Removing unsightly ticks from plots
    plt.xticks(())
    plt.yticks(())

plt.suptitle('BernoulliRBM components', size=30)

# Disregard warnings - our scale might be slightly beyond 0 - 1 and is being clipped
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %% [markdown]
# ### How is this useful?
#
# The matrix of images above shows the RBM components for the model. In a way, it is extracting the important parts across the data set, and we are putting them back into images to visualize what pieces are deemed valuable. While none are identical, we can see that shapes within the image centers consistently contain similar colors, and the regions around that behave similarly. Many edges can be seen in these areas; they are different in each component, but some overlap can certainly be observed.

# %%
for val in [1, 3, 4, 5]:
    
    with open('../../../_Large_datasets/cifar-10-batches-py/data_batch_' + str(val), 'rb') as file:
        my_dict2 = pickle.load(file, encoding='bytes')

    X2 = pd.DataFrame(my_dict2[b'data'])
    y2 = pd.Series(my_dict2[b'labels'])
    X2_scaled = scaler.fit_transform(X2)

    X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2, random_state=42)

    y2_pred = clf_rbm_log.predict(X2_test)
    print(classification_report(y2_test, y2_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.29      0.45      0.36       207
#           1       0.39      0.28      0.33       213
#           2       0.26      0.29      0.28       197
#           3       0.25      0.18      0.21       199
#           4       0.30      0.17      0.22       205
#           5       0.31      0.25      0.28       177
#           6       0.33      0.25      0.28       187
#           7       0.36      0.40      0.38       200
#           8       0.36      0.58      0.44       224
#           9       0.37      0.34      0.35       191
#
# avg / total       0.32      0.32      0.31      2000
#
#              precision    recall  f1-score   support
#
#           0       0.36      0.47      0.41       214
#           1       0.39      0.27      0.32       245
#           2       0.22      0.30      0.25       181
#           3       0.23      0.14      0.18       211
#           4       0.28      0.16      0.20       199
# ...

# %% [markdown]
# ### Notes: Testing other CIFAR test sets
#
# We are getting fairly different results for the other datasets. It seems we are falling victim to overfitting, and predictions are not performing consistently.
