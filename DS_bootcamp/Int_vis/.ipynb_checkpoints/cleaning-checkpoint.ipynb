# %% [markdown]
# remove all trailing spaces - .str.strip()
#
# remove all trailing special characters - \n
#
# change to all one case

# %%
file_name = 'WELLCOME_APCspend2013_forThinkful.csv'
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
apc = pd.read_csv(file_name, encoding='ISO-8859-1', header=0, names=['PMID', 'Publisher', 'Journal', 'Article', 'Cost'])
apc2 = apc.copy()
apc2.head(5)
# Out:
#                     PMID Publisher                 Journal  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                              Article      Cost
# 0  Reduced parahippocampal cortical thickness in ...     £0.00
# 1  Structural characterization of a Model Gram-ne...  £2381.04
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...   £642.56
# 3  Orvinols with mixed kappa/mu opioid receptor a...   £669.64
# 4  Regioselective opening of myo-inositol orthoes...   £685.88

# %%
apc2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2127 entries, 0 to 2126
# Data columns (total 5 columns):
# PMID         1928 non-null object
# Publisher    2127 non-null object
# Journal      2126 non-null object
# Article      2127 non-null object
# Cost         2127 non-null object
# dtypes: object(5)
# memory usage: 83.2+ KB

# %%
apc2.drop(columns='PMID', inplace=True)
apc2['Cost'] = apc2['Cost'].str.lstrip('£')
apc2['Cost'] = apc2['Cost'].str.rstrip('$')
apc2['Cost'] = apc2.Cost.apply(float)
apc2.dropna(subset=['Journal'], inplace=True)
apc2['Journal'] = apc2['Journal'].str.upper()
apc2['Journal'] = apc2['Journal'].str.replace(r'plos', 'PLoS', case=False)
apc2['Journal'] = apc2['Journal'].str.replace(r'plosone', 'PLoS One', case=False)
apc2['Journal'] = apc2['Journal'].str.replace(r'plos one', 'PLoS One', case=False)
apc2['Journal'] = apc2['Journal'].str.replace(r'plos 1', 'PLoS One', case=False)
apc2['Journal'] = apc2['Journal'].str.replace(r'americal', 'AMERICAN', case=False)
apc2['Journal'] = apc2['Journal'].str.replace(r'&', 'and', case=False)
apc2['Journal'] = apc2['Journal'].str.strip()
apc2['Journal'] = apc2['Journal'].str.rstrip('.')
apc2['Journal'] = apc2['Journal'].str.lstrip('THE ')
apc2['Journal'] = apc2['Journal'].str.lstrip('HE ')
apc2['Journal'] = apc2['Journal'].str.replace(r'^ISTORY', 'HISTORY', case=False)
apc2['Journal'] = apc2['Journal'].str.replace(r'^VIDENCE', 'EVIDENCE', case=False)
apc2['Journal'] = apc2['Journal'].str.replace(r'^UROPEAN', 'EUROPEAN', case=False)
apc2['Journal'] = apc2['Journal'].str.replace(r'^XPER', 'EXPER', case=False)

# %%
# Total article counts - top 5
apc2['Journal'].value_counts()[:5]
# Out:
# PLoS One                           206
# JOURNAL OF BIOLOGICAL CHEMISTRY     60
# NEUROIMAGE                          29
# NUCLEIC ACIDS RESEARCH              26
# PLoS PATHOGENS                      24
# Name: Journal, dtype: int64

# %%
apc2.groupby('Journal').mean()
# Out:
#                                                              Cost
# Journal
# ACADEMY OF NUTRITION AND DIETETICS                    2379.540000
# ACS CHEMICAL BIOLOGY                                  1418.186000
# ACS CHEMICAL NEUROSCIENCE                             1186.800000
# ACS NANO                                               668.140000
# ACTA CRYSTALLOGRAPHICA SECTION D,  BIOLOGICAL C...     771.420000
# ACTA CRYSTALLOGRAPHICA SECTION D: BIOLOGICAL CR...     773.740000
# ACTA CRYSTALLOGRAPHICA SECTION F: STRUCTURAL BI...     796.635000
# ACTA CRYSTALLOGRAPHICA, SECTION D                      757.180000
# ACTA CRYSTALLOGRAPHY D                                 774.190000
# ACTA D                                                 750.160000
# ACTA DERMATO VENEREOLOGICA                             653.960000
# ACTA DIABETOLOGICA                                    2336.280000
# ACTA F                                                 754.900000
# ACTA NEUROPATHOL                                      1901.040000
# ACTA NEUROPATHOLOGICA                                 2161.063333
# ACTA OPTHALMOLOGICA                                   2270.160000
# ACTA PHYSIOL                                          1991.500000
# ADDICTION                                             2136.225000
# ADVANCES IN EXPERIMENTAL MEDICINE AND BIOLOGY         1928.457500
# AEMATOLOGICA                                          1567.940000
# AEMATOLOGICA/THE HAEMATOLOGY JOURNAL                   378.700000
# AGE                                                   2170.140000
# AGE AND AGEING                                        2040.000000
# AGEING and SOCIETY                                    1695.000000
# AGING CELL                                            1970.570000
# AIDS                                                  2059.306667
# AIDS BEHAV                                            1834.770000
# AIDS CARE                                             2294.225000
# AIDS JOURNAL                                          2015.720000
# AIDS RESEARCH AND THERAPY                             1240.000000
# ...                                                           ...
# UKARYOTIC CELL                                        1984.670000
# UM RESOUR HEALTH                                      1525.000000
# UMAN BRAIN MAPPING                                    1500.000000
# UMAN MOL GENETICS ONLINE                              2040.000000
# UMAN MOLECULAR GENETICS                              54565.144737
# UMAN MOLECULAR GENETICS ONLINE                        1700.000000
# UMAN MUTATION                                         2148.925000
# UMAN MUTATION: VARIATION, INFORMATICS, AND DISEAS
AN MUTATION: VARIATION, INFORMATICS, AND DISEASE    1500.000
# UMAN REPRODUCTION                                     2040.000
# UMAN RESOURCES FOR HEALTH                             1125.000
# UR J IMMUNOL                                          1834.770
# URBAN HISTORY                                         2034.000
# UROLITHIASIS                                          1112.400
# VACCINE                                               1448.380
# VALUATION IN CLINICAL PRACTICE                        2300.380
# VASCULAR PHARMACOLOGY                                 2352.530
# VET. JOURNAL                                          2480.060
# VETERINARY MICROBIOLOGY                               2451.490
# VETERINARY PARASITOLOGY                             501243.585
# VETERINARY RECORD                                     2040.000
# VETERINARY RESEARCH                                      9.930
# VIROLOGY                                              1928.505
# VIROLOGY JOURNAL                                      1242.000
# VIRUS RESEARCH                                        1947.090
# VISION RESEARCH                                     500727.590
# VISUAL NEUROSCIENCE                                   2034.000
# VODEVO                                                1564.500
# VOLUTION                                              2279.370
# VOLUTIONARY APPLICATIONS                              1524.000
# ZOONOSES AND PUBLIC HEALTH                            2272.150
#
# [869 rows x 1 columns]

# %%
apc2.groupby('Journal').std()
# Out:
#                                                              Cost
# Journal
# ACADEMY OF NUTRITION AND DIETETICS                            NaN
# ACS CHEMICAL BIOLOGY                                   507.309560
# ACS CHEMICAL NEUROSCIENCE                                     NaN
# ACS NANO                                                35.708892
# ACTA CRYSTALLOGRAPHICA SECTION D,  BIOLOGICAL C...            NaN
# ACTA CRYSTALLOGRAPHICA SECTION D: BIOLOGICAL CR...            NaN
# ACTA CRYSTALLOGRAPHICA SECTION F: STRUCTURAL BI...      15.605847
# ACTA CRYSTALLOGRAPHICA, SECTION D                             NaN
# ACTA CRYSTALLOGRAPHY D                                        NaN
# ACTA D                                                        NaN
# ACTA DERMATO VENEREOLOGICA                                    NaN
# ACTA DIABETOLOGICA                                            NaN
# ACTA F                                                        NaN
# ACTA NEUROPATHOL                                              NaN
# ACTA NEUROPATHOLOGICA                                  244.811798
# ACTA OPTHALMOLOGICA                                           NaN
# ACTA PHYSIOL                                                  NaN
# ADDICTION                                              306.481292
# ADVANCES IN EXPERIMENTAL MEDICINE AND BIOLOGY            0.005000
# AEMATOLOGICA                                                  NaN
# AEMATOLOGICA/THE HAEMATOLOGY JOURNAL                          NaN
# AGE                                                    237.785868
# AGE AND AGEING                                                NaN
# AGEING and SOCIETY                                            NaN
# AGING CELL                                                    NaN
# AIDS                                                   281.067979
# AIDS BEHAV                                                    NaN
# AIDS CARE                                              126.415851
# AIDS JOURNAL                                                  NaN
# AIDS RESEARCH AND THERAPY                                     NaN
# ...                                                           ...
# UKARYOTIC CELL                                         468.797654
# UM RESOUR HEALTH                                              NaN
# UMAN BRAIN MAPPING                                            NaN
# UMAN MOL GENETICS ONLINE                                      NaN
# UMAN MOLECULAR GENETICS                             228947.274919
# UMAN MOLECULAR GENETICS ONLINE                                NaN
# UMAN MUTATION                                          229.137952
# UMAN MUTATION: VARIATION, INFORMATICS, AND DISEASE            NaN
# UMAN REPRODUCTION                                             NaN
# UMAN RESOURCES FOR HEALTH                                     NaN
# UR J IMMUNOL                                                  NaN
# URBAN HISTORY                                                 NaN
# UROLITHIASIS                                                  NaN
# VACCINE                                                394.821486
# VALUATION IN CLINICAL PRACTICE                                NaN
# VASCULAR PHARMACOLOGY                                         NaN
# VET. JOURNAL                                                  NaN
# VETERINARY MICROBIOLOGY                                       NaN
# VETERINARY PARASITOLOGY                             705346.672200
# VETERINARY RECORD                                             NaN
# VETERINARY RESEARCH                                           NaN
# VIROLOGY                                               697.850753
# VIROLOGY JOURNAL                                              NaN
# VIRUS RESEARCH                                                NaN
# VISION RESEARCH                                     706076.399327
# VISUAL NEUROSCIENCE                                           NaN
# VODEVO                                                        NaN
# VOLUTION                                               134.562420
# VOLUTIONARY APPLICATIONS                                      NaN
# ZOONOSES AND PUBLIC HEALTH                                    NaN
#
# [869 rows x 1 columns]
