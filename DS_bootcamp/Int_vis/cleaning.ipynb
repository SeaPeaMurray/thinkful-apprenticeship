# %%
file_name = 'WELLCOME_APCspend2013_forThinkful.csv'
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
apc = pd.read_csv(file_name, encoding='ISO-8859-1')

# %%
apc.head(10)
# Out:
#               PMID/PMCID                                     Publisher  \
# 0                    NaN                                           CUP
# 1             PMC3679557                                           ACS
# 2  23043264  PMC3506128                                            ACS
# 3    23438330 PMC3646402                                           ACS
# 4   23438216 PMC3601604                                            ACS
# 5             PMC3579457                                           ACS
# 6             PMC3709265                                           ACS
# 7   23057412 PMC3495574                                            ACS
# 8      PMCID: PMC3780468  ACS (Amercian Chemical Society) Publications
# 9      PMCID: PMC3621575  ACS (Amercian Chemical Society) Publications
#
#                     Journal title  \
# 0          Psychological Medicine
# 1               Biomacromolecules
# 2                      J Med Chem
# 3                      J Med Chem
# ...

# %%
apc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2127 entries, 0 to 2126
# Data columns (total 5 columns):
# PMID/PMCID                                             1928 non-null object
# Publisher                                              2127 non-null object
# Journal title                                          2126 non-null object
# Article title                                          2127 non-null object
# COST (£) charged to Wellcome (inc VAT when charged)    2127 non-null object
# dtypes: object(5)
# memory usage: 83.2+ KB

# %%
apc.isnull().sum()
# Out:
# PMID/PMCID                                             199
# Publisher                                                0
# Journal title                                            1
# Article title                                            0
# COST (£) charged to Wellcome (inc VAT when charged)      0
# dtype: int64

# %%
apc[apc['PMID/PMCID'].isna()]
# Out:
#      PMID/PMCID                                     Publisher  \
# 0           NaN                                           CUP
# 21          NaN                     American Chemical Society
# 43          NaN              American Psychiatric Association
# 93          NaN             American Society for Microbiology
# 100         NaN                American Society for Nutrition
# 101         NaN               American Society of Haematology
# 102         NaN               American Society of Haematology
# 104         NaN                American Society of Hematology
# 114         NaN  American Speech-Language-Hearing Association
# 126         NaN                                         ASBMB
# 252         NaN                                           BMC
# 258         NaN                                           BMC
# 261         NaN                                           BMC
# 280         NaN                                           BMJ
# ...

# %%
apc.describe()
# Out:
#         PMID/PMCID Publisher Journal title  \
# count         1928      2127          2126
# unique        1880       299           984
# top     In Process  Elsevier      PLoS One
# freq             7       387            92
#
#                                             Article title  \
# count                                                2127
# unique                                               2126
# top     Exclusive breastfeeding, diarrhoel morbidity a...
# freq                                                    2
#
#        COST (£) charged to Wellcome (inc VAT when charged)
# count                                                2127
# unique                                               1402
# top                                              £2040.00
# freq                                                   94

# %%
apc['COST (£) charged to Wellcome (inc VAT when charged)'].str.split('£', expand=True)
# Out:
#      0         1
# 0           0.00
# 1        2381.04
# 2         642.56
# 3         669.64
# 4         685.88
# 5        2392.20
# 6        2367.95
# 7         649.33
# 8        1294.59
# 9        1294.78
# 10       1329.69
# 11       1287.20
# 12       1324.66
# 13        665.64
# 14       1006.72
# 15        238.08
# 16        265.67
# 17       2035.00
# 18       3108.08
# 19       1267.76
# 20       2286.73
# 21        947.07
# 22       1186.80
# 23        642.89
# 24       1533.29
# 25       2082.74
# 26       2314.10
# 27        759.67
# 28       1565.26
# 29        572.74
# ...  ..      ...
# 2097     2236.02
# 2098     2275.02
# 2099     2373.57
# 2100      791.19
# 2101     1551.49
# 2102     1961.68
# 2103     1982.35
# 2104     2239.22
# 2105     2377.65
# 2106     2272.15
# 2107     1900.70
# 2108     3026.17
# 2109     1851.15
# 2110     1812.89
# 2111     1816.70
# 2112     2168.05
# 2113     1409.96
# 2114     2400.00
# 2115     1968.63
# 2116     2015.72
# ...

# %%
apc.loc[2107]
# Out:
# PMID/PMCID                                                                                    PMC3440570
# Publisher                                                             Wiley-Blackwell, John Wiley & Sons
# Journal title                                                        American Journal of Transplantation
# Article title                                          Low dose rapamycin treatment increases the abi...
# COST (£) charged to Wellcome (inc VAT when charged)                                             £1900.70
# Name: 2107, dtype: object

# %%
apc['Publisher'].unique()
# Out:
# array(['CUP', 'ACS', 'ACS (Amercian Chemical Society) Publications',
#        'ACS Publications', 'AGA Institute', 'AMBSB',
#        'American Association of Immunologists',
#        'American Chemical Society', 'AMERICAN CHEMICAL SOCIETY',
#        'American Chemical Society Publications',
#        'American College of Chest Physicians',
#        'American Physiological Society',
#        'American Psychiatric Association',
#        'American Psychiatric Publishing',
#        'American Psychological Association',
#        'American Psychological Association ',
#        'American Public Health Association',
#        'American Soc for Biochemistry and Molecular Biology',
#        'American Society for Biochemistry and Molecular Biolgy',
#        'American Society for Biochemistry and Molecular Biology',
#        'American Society for Biochemistry and Molecular Biology ',
#        'American Society for Investigative Pathology',
#        'American Society for Microbiology',
# ...

# %%
apc['Publisher'].value_counts()
# Out:
# Elsevier                                                                             387
# Public Library of Science                                                            278
# Wiley                                                                                136
# Springer                                                                              81
# Oxford University Press                                                               77
# Wiley-Blackwell                                                                       56
# OUP                                                                                   56
# ASBMB                                                                                 46
# Nature Publishing Group                                                               45
# BioMed Central                                                                        40
# ...

# %%
apc[apc['Publisher'].str.contains('chem', case=False)]['Publisher'].value_counts()
# Out:
# American Society for Biochemistry and Molecular Biology             18
# American Chemical Society                                           14
# ACS (Amercian Chemical Society) Publications                         5
# The American Chemical Society Petroleum Research Trust               4
# Biochem Journal                                                      2
# American Society for Biochemistry and Molecular Biolgy               1
# American Society for Biochemistry and Molecular Biology              1
# AMERICAN CHEMICAL SOCIETY                                            1
# Royal Society of Chemistry                                           1
# Royal Society for Chemistry                                          1
# American Chemical Society Publications                               1
# The American Society for Biochemistry and Molecular Biology          1
# American Soc for Biochemistry and Molecular Biology                  1
# ...

# %%
def fix(frame):
