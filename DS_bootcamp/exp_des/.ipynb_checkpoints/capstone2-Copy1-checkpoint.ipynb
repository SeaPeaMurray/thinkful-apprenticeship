# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
sns.set_style('dark')
# %matplotlib inline

kick1 = pd.read_csv('../../../kickstarter_set/ks-projects-201801.csv')
kick1.drop(columns=['ID', 'goal', 'currency', 'pledged'], inplace=True)
kick1.loc[:,['deadline', 'launched']] = kick1[['deadline', 'launched']].apply(pd.to_datetime)
kick1.head()
# Out:
#                                                 name        category  \
# 0                    The Songs of Adelaide & Abullah          Poetry
# 1      Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film
# 2                                     Where is Hank?  Narrative Film
# 3  ToshiCapital Rekordz Needs Help to Complete Album           Music
# 4  Community Film Project: The Art of Neighborhoo...    Film & Video
#
#   main_category   deadline            launched     state  backers country  \
# 0    Publishing 2015-10-09 2015-08-11 12:12:28    failed        0      GB
# 1  Film & Video 2017-11-01 2017-09-02 04:43:57    failed       15      US
# 2  Film & Video 2013-02-26 2013-01-12 00:20:50    failed        3      US
# 3         Music 2012-04-16 2012-03-17 03:24:11    failed        1      US
# 4  Film & Video 2015-08-29 2015-07-04 08:35:03  canceled       14      US
#
#    usd pledged  usd_pledged_real  usd_goal_real
# 0          0.0               0.0        1533.95
# ...

# %%
kick1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378661 entries, 0 to 378660
# Data columns (total 11 columns):
# name                378657 non-null object
# category            378661 non-null object
# main_category       378661 non-null object
# deadline            378661 non-null datetime64[ns]
# launched            378661 non-null datetime64[ns]
# state               378661 non-null object
# backers             378661 non-null int64
# country             378661 non-null object
# usd pledged         374864 non-null float64
# usd_pledged_real    378661 non-null float64
# usd_goal_real       378661 non-null float64
# dtypes: datetime64[ns](2), float64(3), int64(1), object(5)
# memory usage: 31.8+ MB

# %%
kick1.describe()
# Out:
#              backers   usd pledged  usd_pledged_real  usd_goal_real
# count  378661.000000  3.748640e+05      3.786610e+05   3.786610e+05
# mean      105.617476  7.036729e+03      9.058924e+03   4.545440e+04
# std       907.185035  7.863975e+04      9.097334e+04   1.152950e+06
# min         0.000000  0.000000e+00      0.000000e+00   1.000000e-02
# 25%         2.000000  1.698000e+01      3.100000e+01   2.000000e+03
# 50%        12.000000  3.947200e+02      6.243300e+02   5.500000e+03
# 75%        56.000000  3.034090e+03      4.050000e+03   1.550000e+04
# max    219382.000000  2.033899e+07      2.033899e+07   1.663614e+08

# %%
july = kick1[kick1.launched.dt.month == 7]['usd pledged']
june = kick1[kick1.launched.dt.month == 6]['usd pledged']

# %%
mylist = []
for val in range(1, 13):
    mylist.append(kick1[kick1.launched.dt.month == val]['usd pledged'].dropna())

# %%
month = np.array(kick1[kick1.launched.dt.month == 1]['usd pledged'])

# %%
mylist = []
mylist.append(kick1[kick1.launched.dt.month == 1]['usd pledged'])

# %%
mylist
# Out:
# [2            220.00
#  15           664.00
#  23             6.18
#  47          9401.00
#  50         61365.16
#  56             0.00
#  82          4045.00
#  91           474.00
#  131         8345.98
#  148            0.00
#  161          942.25
#  174         2161.00
#  175       843743.00
#  191          642.00
#  197          115.05
#  206            5.00
#  214            0.00
#  221            1.00
#  224           20.00
#  257           52.00
#  270          917.10
#  282         1145.00
#  290         2510.00
#  293         1278.00
#  295          734.39
#  368            0.00
#  379         3775.00
#  400         6000.00
#  405         8294.63
#  417         1189.00
#              ...
#  378160      2382.00
#  378174     22357.00
#  378181     38105.22
#  378183         1.00
#  378197       632.00
#  378238         0.00
#  378243     11542.00
#  378256        10.00
#  378276        57.00
#  378309       440.00
#  378311       710.00
#  378352       120.00
# ...

# %%
month + 1 = mylist[1]
# Out:
#   File "<ipython-input-84-0d4ab0bff188>", line 1
#     month + 1 = mylist[1]
#                          ^
# SyntaxError: can't assign to operator

# %%
kick1.launched.dt.month
# Out:
# 0          8
# 1          9
# 2          1
# 3          3
# 4          7
# 5          2
# 6         12
# 7          2
# 8          4
# 9          7
# 10         9
# 11         3
# 12         9
# 13         2
# 14         4
# 15         1
# 16        10
# 17         4
# 18         8
# 19         5
# 20        11
# 21         8
# 22         5
# 23         1
# 24        10
# 25        12
# 26        12
# 27        11
# 28        12
# 29         4
#           ..
# 378631     9
# 378632     5
# 378633    11
# 378634    11
# 378635     8
# 378636    11
# 378637     8
# 378638     7
# 378639    11
# 378640     8
# 378641     7
# 378642    10
# 378643     5
# 378644    11
# 378645     9
# 378646    10
# 378647     8
# 378648     1
# 378649     2
# 378650     7
# 378651     2
# 378652     3
# 378653     2
# 378654     3
# 378655     8
# 378656     9
# 378657     6
# 378658     7
# 378659     1
# 378660     7
# Name: launched, Length: 378661, dtype: int64

# %%
stats.f_oneway(mylist)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-9b05baf742d2> in <module>()
# ----> 1 stats.f_oneway(mylist)
#
# ~\Anaconda3\lib\site-packages\scipy\stats\stats.py in f_oneway(*args)
#    2905
#    2906     """
# -> 2907     args = [np.asarray(arg, dtype=float) for arg in args]
#    2908     # ANOVA on N groups, each in its own array
#    2909     num_groups = len(args)
#
# ~\Anaconda3\lib\site-packages\scipy\stats\stats.py in <listcomp>(.0)
#    2905
#    2906     """
# -> 2907     args = [np.asarray(arg, dtype=float) for arg in args]
#    2908     # ANOVA on N groups, each in its own array
#    2909     num_groups = len(args)
#
# ~\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     499
#     500     """
# --> 501     return array(a, dtype, copy=False, order=order)
#     502
#     503
#
# ...

# %%
stats.ttest_ind(mylist[0], mylist[1])
# Out:
# Ttest_indResult(statistic=-1.6217408231578054, pvalue=0.10486440063009411)

# %%
mylist[-1]
# Out:
# [1205.0,
#  15827.0,
#  0.0,
#  167.7,
#  17.0,
#  83.0,
#  95.87,
#  3755.0,
#  200.0,
#  850.0,
#  113.0,
#  0.0,
#  1.0,
#  375.22,
#  22421.0,
#  1067.0,
#  1591.0,
#  0.0,
#  8927.74,
#  1810.0,
#  0.0,
#  13.39,
#  50.0,
#  120.0,
#  0.0,
#  0.0,
#  4370.0,
#  5.0,
#  2236.44,
#  0.0,
#  1.0,
#  1195.0,
#  5001.31,
#  165.0,
#  8540.0,
#  53.52,
#  0.0,
#  103114.5,
#  1.0,
#  5850.0,
#  1.0,
#  7.0,
#  1026.0,
#  23098.0,
#  1.0,
#  52837.51,
#  54.0,
#  1870.0,
#  190.0,
#  10120.5,
#  1390.0,
#  3355.0,
#  1785.0,
#  26695.0,
#  0.0,
#  1656.0,
#  5.0,
#  21.0,
#  3155.0,
#  25.0,
#  0.0,
#  645.0,
#  315.0,
#  17.0,
#  122.71,
#  430.0,
#  650.0,
#  6.0,
#  0.0,
#  5.19,
#  667.0,
#  15.0,
#  0.0,
#  7.0,
#  4210.0,
#  0.0,
#  1.0,
#  260.0,
#  100.0,
#  0.0,
#  10339.0,
#  45.0,
#  105.0,
#  10195.77,
#  823.0,
#  0.0,
#  0.0,
#  13250.0,
#  5506.0,
#  1758.0,
#  690.0,
#  4784.38,
#  0.0,
#  0.0,
#  11880.18,
#  1575.0,
#  17332.0,
#  5902.0,
#  0.0,
#  68.52,
#  544.68,
# ...

# %%
for i, array in enumerate(mylist):
    month = array

# %%
month
# Out:
# [1205.0,
#  15827.0,
#  0.0,
#  167.7,
#  17.0,
#  83.0,
#  95.87,
#  3755.0,
#  200.0,
#  850.0,
#  113.0,
#  0.0,
#  1.0,
#  375.22,
#  22421.0,
#  1067.0,
#  1591.0,
#  0.0,
#  8927.74,
#  1810.0,
#  0.0,
#  13.39,
#  50.0,
#  120.0,
#  0.0,
#  0.0,
#  4370.0,
#  5.0,
#  2236.44,
#  0.0,
#  1.0,
#  1195.0,
#  5001.31,
#  165.0,
#  8540.0,
#  53.52,
#  0.0,
#  103114.5,
#  1.0,
#  5850.0,
#  1.0,
#  7.0,
#  1026.0,
#  23098.0,
#  1.0,
#  52837.51,
#  54.0,
#  1870.0,
#  190.0,
#  10120.5,
#  1390.0,
#  3355.0,
#  1785.0,
#  26695.0,
#  0.0,
#  1656.0,
#  5.0,
#  21.0,
#  3155.0,
#  25.0,
#  0.0,
#  645.0,
#  315.0,
#  17.0,
#  122.71,
#  430.0,
#  650.0,
#  6.0,
#  0.0,
#  5.19,
#  667.0,
#  15.0,
#  0.0,
#  7.0,
#  4210.0,
#  0.0,
#  1.0,
#  260.0,
#  100.0,
#  0.0,
#  10339.0,
#  45.0,
#  105.0,
#  10195.77,
#  823.0,
#  0.0,
#  0.0,
#  13250.0,
#  5506.0,
#  1758.0,
#  690.0,
#  4784.38,
#  0.0,
#  0.0,
#  11880.18,
#  1575.0,
#  17332.0,
#  5902.0,
#  0.0,
#  68.52,
#  544.68,
# ...

# %%
np.log(june.dropna() + 1).hist(alpha=0.5,figsize=(16,10))
np.log(july.dropna() + 1).hist(alpha=0.5)

# %%
sns.pairplot(kick1)
# Out:
# C:\Users\seapea\Anaconda3\lib\site-packages\numpy\lib\histograms.py:746: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\seapea\Anaconda3\lib\site-packages\numpy\lib\histograms.py:747: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
kick1.state.value_counts()
# Out:
# failed        197719
# successful    133956
# canceled       38779
# undefined       3562
# live            2799
# suspended       1846
# Name: state, dtype: int64

# %%
kick1.main_category.value_counts()
# Out:
# Film & Video    63585
# Music           51918
# Publishing      39874
# Games           35231
# Technology      32569
# Design          30070
# Art             28153
# Food            24602
# Fashion         22816
# Theater         10913
# Comics          10819
# Photography     10779
# Crafts           8809
# Journalism       4755
# Dance            3768
# Name: main_category, dtype: int64

# %%
kick1['usd_pledged_real'] / kick1['usd_goal_real']
# Out:
# 0          0.000000
# 1          0.080700
# 2          0.004889
# 3          0.000200
# 4          0.065795
# 5          1.047500
# 6          1.205000
# 7          0.018120
# 8          0.065864
# 9          0.096009
# 10         0.000000
# 11         1.016000
# 12         0.000000
# 13         0.000000
# 14        18.834995
# 15         0.265600
# 16         0.263333
# 17         0.263000
# 18         1.000000
# 19         0.356200
# 20         1.713400
# 21         0.000400
# 22         0.185714
# 23         0.095957
# 24         4.009486
# 25         1.582700
# 26         0.000000
# 27         2.754125
# 28         1.123784
# 29         1.151546
#             ...
# 378631     1.386150
# 378632     0.000000
# 378633     0.465720
# 378634     0.882750
# 378635     0.087500
# 378636     1.087000
# 378637     1.024500
# 378638     0.003600
# 378639     1.115800
# 378640     0.100000
# 378641     0.000000
# 378642     1.246007
# 378643     0.000000
# 378644     1.762571
# ...

# %%
kick1.name.apply(lambda x: len(str(x)))
# Out:
# 0         31
# 1         45
# 2         14
# 3         49
# 4         58
# 5         20
# 6         60
# 7         49
# 8         53
# 9         57
# 10        19
# 11        16
# 12        18
# 13        59
# 14        57
# 15        14
# 16         9
# 17        32
# 18        35
# 19         8
# 20        37
# 21        32
# 22        30
# 23        49
# 24        27
# 25        52
# 26        20
# 27        19
# 28        52
# 29        29
#           ..
# 378631    58
# 378632     8
# 378633    51
# 378634    13
# 378635    56
# 378636    29
# 378637    24
# 378638    19
# 378639    49
# 378640    25
# 378641    48
# 378642    55
# 378643    30
# 378644    20
# 378645    43
# 378646    19
# 378647    21
# 378648    43
# 378649    45
# 378650    26
# 378651    12
# 378652    27
# 378653     7
# 378654    37
# 378655    26
# 378656    49
# 378657     9
# 378658    71
# 378659    24
# 378660    33
# Name: name, Length: 378661, dtype: int64

# %%
kick1.launched.dt.month.value_counts()
# Out:
# 7     36367
# 3     33946
# 10    33490
# 11    32890
# 5     32888
# 6     32623
# 8     32291
# 4     32260
# 9     31069
# 2     29732
# 1     27841
# 12    23264
# Name: launched, dtype: int64
